# %% [markdown]
# <div style="border:4px solid #012622; border-radius:30px; padding: 30px; background-size: cover; background: linear-gradient(to right, #FF5733, #33FF57, #3357FF, #FF33A1)">
# <h1 style="
#     color:#FFFFFF;
#     text-align: center;
#     text-shadow: 2px 2px 4px #000000;
#     font-family: Arial, sans-serif;
#     font-size: 42px;
#     font-weight: bold;
# ">
#      🍆 Fruits and Vegetables Image Recognition Dataset 🍉
# </h1>
# </div>

# %% [markdown]
# <img src='https://cdn.freshfruitportal.com/2018/12/Mix-Frutas-_40917862-v-2.jpg'>
# <a href='https://avatars.mds.yandex.net/i?id=417fe08cd0cb449823b12a5f7e3120625357f6a7-6419094-images-thumbs&n=13'> Image Source</a>

# %% [markdown]
# <div style="border:4px solid #012622; border-radius:30px; padding: 30px; background-size: cover; background: linear-gradient(to right, #FF5733, #33FF57, #3357FF, #FF33A1)">
# <p>
#
# <h1 style="text-align: center; font-size:350">About Dataset</h1>
# <h3 style="font-size:200%">Context:</h3>
# <b style="font-size:150%;">
# <ul>
#     <li><strong>Fruits:</strong> banana, apple, pear, grapes, orange, kiwi, watermelon, pomegranate, pineapple, mango</li>
#     <li><strong>Vegetables:</strong> cucumber, carrot, capsicum, onion, potato, lemon, tomato, raddish, beetroot, cabbage, lettuce, spinach, soy bean, cauliflower, bell pepper, chilli pepper, turnip, corn, sweetcorn, sweet potato, paprika, jalepeño, ginger, garlic, peas, eggplant</li>
# </ul>
# <h3 style="font-size:140%">Content</h3>
# <ul>
#      <li><strong>Train:</strong> Contains 100 images per category.</li>
#      <li><strong>Test:</strong> Contains 10 images per category.</li>
#      <li><strong>Validation:</strong> Contains 10 images per category.</li>
# </ul>
# </b>
# </p>
# </div>
#
# <a href="https://www.kaggle.com/datasets/kritikseth/fruit-and-vegetable-image-recognition/data">Click for Source</a>

# %% [markdown]
# <div style="border: 3px solid none;
#     width: 40%; margin: 0 auto;
#     background-size: cover;
#     background: linear-gradient(135deg,
#               #4B9B3A,
#               #A8D8B9);
#             background-size: 20px 20px;
#             position: relative;
#     background-attachment: fixed;
#     font-family: 'Times New Roman';
#     font-size: 140%; padding: 15px;
#     font-weight: bold; line-height: 1.6;
#     text-align: center;">
#
# <div style="font-size: 170%; margin-bottom: 8px;">Table of Contents 📑</div>
# </div>
# <div style="width: 40%; margin: 0 auto;
#             background: linear-gradient(to bottom,
#               #FF7F7F 70%,
#               #FFB2B2 70%);
#             position: relative;">
#
#   <!-- Siyah çekirdekler -->
#   <div style="position: absolute; width: 10px; height: 15px; background: rgba(0, 0, 0, 0.3);
#               border-radius: 50%; top: 50px; right: 70px;"></div>
#   <div style="position: absolute; width: 10px; height: 15px; background: rgba(0, 0, 0, 0.3);
#               border-radius: 50%; top: 60px; right: 100px;"></div>
#   <div style="position: absolute; width: 10px; height: 15px; background: rgba(0, 0, 0, 0.3);
#               border-radius: 50%; top: 100px; right: 30px;"></div>
#   <div style="position: absolute; width: 10px; height: 15px; background: rgba(0, 0, 0, 0.3);
#               border-radius: 50%; top: 130px; right: 50px;"></div>
#   <div style="position: absolute; width: 10px; height: 15px; background: rgba(0, 0, 0, 0.3);
#               border-radius: 50%; top: 180px; left: 1px;"></div>
#   <div style="position: absolute; width: 10px; height: 15px; background: rgba(0, 0, 0, 0.3);
#               border-radius: 50%; top: 170px; right: 10px;"></div>
#   <div style="position: absolute; width: 10px; height: 15px; background: rgba(0, 0, 0, 0.3);
#               border-radius: 50%; top: 170px; right: 150px;"></div>
#   <div style="position: absolute; width: 10px; height: 15px; background: rgba(0, 0, 0, 0.3);
#               border-radius: 50%; top: 170px; left: 170px;"></div>
#   <div style="position: absolute; width: 10px; height: 15px; background: rgba(0, 0, 0, 0.3);
#               border-radius: 50%; top: 130px; right: 165px;"></div>
#   <div style="position: absolute; width: 10px; height: 15px; background: rgba(0, 0, 0, 0.3);
#               border-radius: 50%; top: 68px; right: 1680px;"></div>
#   <div style="position: absolute; width: 10px; height: 15px; background: rgba(0, 0, 0, 0.3);
#               border-radius: 50%; top: 50px; left: 170px;"></div>
#   <div style="position: absolute; width: 10px; height: 15px; background: rgba(0, 0, 0, 0.3);
#               border-radius: 50%; top: 75px; right: 165px;"></div>
#   <div style="position: absolute; width: 10px; height: 15px; background: rgba(0, 0, 0, 0.3);
#               border-radius: 50%; top: 110px; right: 168px;"></div>
#   <div style="position: absolute; width: 10px; height: 15px; background: rgba(0, 0, 0, 0.3);
#               border-radius: 50%; top: 10px; right: 10px;"></div>
#   <div style="position: absolute; width: 10px; height: 15px; background: rgba(0, 0, 0, 0.3);
#               border-radius: 50%; top: 220px; right: 18px;"></div>
#
#
#   <div style="position: absolute; width: 10px; height: 15px; background: rgba(0, 0, 0, 0.3);
#               border-radius: 50%; top: 30px; left: 80px;"></div>
#   <div style="position: absolute; width: 10px; height: 15px; background: rgba(0, 0, 0, 0.3);
#               border-radius: 50%; top: 10px; left: 35px;"></div>
#   <div style="position: absolute; width: 10px; height: 15px; background: rgba(0, 0, 0, 0.3);
#               border-radius: 50%; top: 25px; left: 50px;"></div>
#   <div style="position: absolute; width: 10px; height: 15px; background: rgba(0, 0, 0, 0.3);
#               border-radius: 50%; top: 100px; left: 45px;"></div>
#   <div style="position: absolute; width: 10px; height: 15px; background: rgba(0, 0, 0, 0.3);
#               border-radius: 50%; top: 120px; left: 15px;"></div>
#   <div style="position: absolute; width: 10px; height: 15px; background: rgba(0, 0, 0, 0.3);
#               border-radius: 50%; top: 80px; left: 90px;"></div>
#   <div style="position: absolute; width: 10px; height: 15px; background: rgba(0, 0, 0, 0.3);
#               border-radius: 50%; top: 210px; left: 14px;"></div>
# <ol>
#     <br>
#     <strong><li><a href="#1"> The Aim of Project</a></strong>
#     <strong><li><a href="#2"> Libraries</a></strong>
#     <strong><li><a href="#3"> Import Data</a></strong>
#     <ul style="list-style-type: none; padding-left: 0;">
#             <li>-<a href="#3.1">Load Train Data</a></li>
#             <li>-<a href="#3.2">Load Data with TF DataFrame</a></li>
#     </ul>
#     <strong><li><a href="#4"> Visualize Classes</a></strong>
#     <strong><li><a href="#5"> Data Augmentation</a></li></strong>
#     <strong><li><a href="#6"> Build and Train the Model</a></strong>
#     <ul style="list-style-type: none; padding-left:0;">
#             <li>-<a href=#6.1>Basic Model with no Augmentation</a></li>
#             <li>-<a href=#6.2>Basic Model with Augmentation</a></li>
#             <li>-<a href=#6.3>MobilenetV2 model with no Augmentation</a></li>
#             <li>-<a href=#6.4>MobilenetV2 model with Augmentation</a></li>
#     </ul>
#     <strong><li><a href="#7"> Result</a></li>
# </ol>
# <br>
# </div>

# %% [markdown]
# <a id="1"></a>
# ## 1-The Aim of Project
# My aim in this project is to develop and compare models capable of identifying and classifying different types of fruits and vegetables from images. First, I will build and train a CNN model. Then,  I will apply transfer learning techniques to build new models. Finally, I will compare and analyze the results of these models.

# %% [markdown]
# <a id="2"></a>
# ## 2-Libraries

# %%
pip install visualkeras
# Out:
# Requirement already satisfied: visualkeras in c:\users\cream\appdata\local\programs\python\python312\lib\site-packages (0.1.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\cream\appdata\local\programs\python\python312\lib\site-packages (from visualkeras) (11.2.1)
# Requirement already satisfied: numpy>=1.18.1 in c:\users\cream\appdata\local\programs\python\python312\lib\site-packages (from visualkeras) (2.1.3)
# Requirement already satisfied: aggdraw>=1.3.11 in c:\users\cream\appdata\local\programs\python\python312\lib\site-packages (from visualkeras) (1.3.19)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import cv2
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
import seaborn as sns
from PIL import Image 
from pathlib import Path
import visualkeras

import tensorflow as tf
from tensorflow import keras
import keras_cv
from tensorflow.keras import regularizers, layers, models
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization, GlobalAveragePooling2D
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau 
from keras.optimizers import Adam
from keras.regularizers import l2
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

import warnings 

warnings.filterwarnings('ignore');

# %% [markdown]
# <a id="3"></a>
# ## 3-Import Data

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("kritikseth/fruit-and-vegetable-image-recognition")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: C:\Users\cream\.cache\kagglehub\datasets\kritikseth\fruit-and-vegetable-image-recognition\versions\8

# %%
train_path = "dataset_19/train"
test_path = "dataset_19/test"
validation_path = "dataset_19/validation"

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h4>Warning!</h4>
# I will not use the images in the test and validation sections as they are taken from the train images.
# </div>

# %%
num_classes = len(os.listdir(train_path))
num_classes
# Out:
# 19

# %%
label_list = os.listdir(train_path)
label_list
# Out:
# ['asparagus',
#  'Baby Corn',
#  'Beef Tomato',
#  'chili',
#  'Chinese chives',
#  'coriander',
#  'French beans',
#  'Garlic sprouts',
#  'Green bamboo shoots',
#  'Okra',
#  'onion',
#  'pumpkin',
#  'Shallots',
#  'sweet potato',
#  'Sweet potato leaves',
#  'Water Lily',
#  'White radish',
#  'Winter melon',
#  'zucchini']

# %%
def load_image(data_path, img_size=224):
    X=[]
    y=[]
    label_list = os.listdir(data_path)
    label_num = np.arange(0,len(label_list))
    labels = dict(zip(label_list, label_num))
    
    for label in labels:
        path = Path(data_path)/label
        for img_name in os.listdir(path):
            img_path = Path(path,img_name)
            img = cv2.imread(img_path)
            print(img_path)
            if img is None:
                print(f'Skip {img_path} could not read image')
                continue 
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            img = cv2.resize(img, (img_size, img_size))
            X.append(img)
            y.append(labels[label])
    return np.array(X), np.array(y)

# %% [markdown]
# <a id="3.1"></a>
# ### Load Train Data

# %%
X_train, y_train = load_image(train_path)
X_train = X_train.astype('float32')/255.0
# Out:
# dataset_19\train\asparagus\asparagus1002.jpeg
# dataset_19\train\asparagus\asparagus1003.jpg
# dataset_19\train\asparagus\asparagus1005.jpg
# dataset_19\train\asparagus\asparagus1006.jpg
# dataset_19\train\asparagus\asparagus1007.jpg
# dataset_19\train\asparagus\asparagus1008.jpg
# dataset_19\train\asparagus\asparagus1010.jpg
# dataset_19\train\asparagus\asparagus1012.jpg
# dataset_19\train\asparagus\asparagus1015.jpg
# dataset_19\train\asparagus\asparagus1017.jpg
# dataset_19\train\asparagus\asparagus1018.jpg
# dataset_19\train\asparagus\asparagus1020.jpg
# dataset_19\train\asparagus\asparagus1023.jpg
# dataset_19\train\asparagus\asparagus1024.jpeg
# dataset_19\train\asparagus\asparagus1026.jpg
# dataset_19\train\asparagus\asparagus1027.jpg
# dataset_19\train\asparagus\asparagus1028.jpg
# dataset_19\train\asparagus\asparagus1031.jpg
# dataset_19\train\asparagus\asparagus1032.jpg
# dataset_19\train\asparagus\asparagus1033.jpg
# dataset_19\train\asparagus\asparagus1035.jpeg
# dataset_19\train\asparagus\asparagus1037.jpg
# dataset_19\train\asparagus\asparagus1038.jpg
# dataset_19\train\asparagus\asparagus1039.jpg
# dataset_19\train\asparagus\asparagus1040.jpg
# dataset_19\train\asparagus\asparagus1041.jpg
# dataset_19\train\asparagus\asparagus1042.jpg
# dataset_19\train\asparagus\asparagus1043.jpg
# dataset_19\train\asparagus\asparagus1044.jpg
# dataset_19\train\asparagus\asparagus1046.jpeg
# dataset_19\train\asparagus\asparagus1048.jpg
# dataset_19\train\asparagus\asparagus1049.jpg
# dataset_19\train\asparagus\asparagus1050.jpeg
# dataset_19\train\asparagus\asparagus1053.jpg
# dataset_19\train\asparagus\asparagus1055.jpg
# dataset_19\train\asparagus\asparagus1056.jpg
# dataset_19\train\asparagus\asparagus1057.jpeg
# dataset_19\train\asparagus\asparagus1059.jpg
# dataset_19\train\asparagus\asparagus1060.jpg
# dataset_19\train\asparagus\asparagus1061.jpg
# dataset_19\train\asparagus\asparagus1063.jpg
# dataset_19\train\asparagus\asparagus1064.jpg
# dataset_19\train\asparagus\asparagus1067.jpg
# dataset_19\train\asparagus\asparagus1068.jpeg
# dataset_19\train\asparagus\asparagus1070.jpg
# dataset_19\train\asparagus\asparagus1072.jpg
# dataset_19\train\asparagus\asparagus1073.jpg
# dataset_19\train\asparagus\asparagus1074.jpg
# dataset_19\train\zucchini\zucchini1401.jpg
# dataset_19\train\zucchini\zucchini1402.jpg
# dataset_19\train\zucchini\zucchini1408.jpg
# dataset_19\train\zucchini\zucchini1409.jpg
# dataset_19\train\zucchini\zucchini1411.jpg
# dataset_19\train\zucchini\zucchini1414.jpg
# dataset_19\train\zucchini\zucchini1416.jpg
# dataset_19\train\zucchini\zucchini1417.jpg
# dataset_19\train\zucchini\zucchini1418.jpg
# dataset_19\train\zucchini\zucchini1419.jpg
# dataset_19\train\zucchini\zucchini1421.jpg
# dataset_19\train\zucchini\zucchini1425.jpg
# dataset_19\train\zucchini\zucchini1428.jpg
# dataset_19\train\zucchini\zucchini1429.jpg
# dataset_19\train\zucchini\zucchini1431.jpg
# dataset_19\train\zucchini\zucchini1432.jpg
# dataset_19\train\zucchini\zucchini1434.jpeg
# dataset_19\train\zucchini\zucchini1435.jpg
# dataset_19\train\zucchini\zucchini1436.jpg
# dataset_19\train\zucchini\zucchini1437.jpg
# dataset_19\train\zucchini\zucchini1438.jpg
# dataset_19\train\zucchini\zucchini1439.jpg
# dataset_19\train\zucchini\zucchini1440.jpg
# dataset_19\train\zucchini\zucchini1441.jpg
# dataset_19\train\zucchini\zucchini1442.jpg
# dataset_19\train\zucchini\zucchini1444.jpg
# dataset_19\train\zucchini\zucchini1446.jpg
# dataset_19\train\zucchini\zucchini1447.jpg
# dataset_19\train\zucchini\zucchini1449.jpg
# dataset_19\train\zucchini\zucchini1450.jpg
# dataset_19\train\zucchini\zucchini1451.jpg
# dataset_19\train\zucchini\zucchini1453.jpg
# dataset_19\train\zucchini\zucchini1454.jpg
# dataset_19\train\zucchini\zucchini1456.jpeg
# dataset_19\train\zucchini\zucchini1459.jpg
# dataset_19\train\zucchini\zucchini1461.jpg
# dataset_19\train\zucchini\zucchini1466.jpg

# %% [markdown]
# <a id="3.2"></a>
# ### Loading with tf Dataframe

# %% [markdown]
# <div class="alert alert-block alert-info"> I will use the one above in the visualization phase, and this one in the model and data augmentation phases.
# </div>

# %%
num_classes = len(os.listdir(train_path))
num_classes

batch_size = 32
img_size = (128, 128)

# Eğitim setini yükleme
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    train_path,
    image_size=img_size,
    batch_size=batch_size,
)
classes = train_ds.class_names
normalization_layer = tf.keras.layers.Rescaling(1./255)
train_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))

train_ds = train_ds.shuffle(buffer_size=1000)

train_size = int(0.8 * len(train_ds)) 
test_size = len(train_ds) - train_size

train_dataset = train_ds.take(train_size)
test_dataset = train_ds.skip(train_size)

print(classes)
# Out:
# Found 6826 files belonging to 19 classes.
# ['Baby Corn', 'Beef Tomato', 'Chinese chives', 'French beans', 'Garlic sprouts', 'Green bamboo shoots', 'Okra', 'Shallots', 'Sweet potato leaves', 'Water Lily', 'White radish', 'Winter melon', 'asparagus', 'chili', 'coriander', 'onion', 'pumpkin', 'sweet potato', 'zucchini']

# %% [markdown]
# **Val data and Text data are almost same. I will use Text data.**

# %% [markdown]
# <a id="4"></a>
# ## 4-Visualize Classes

# %%
def count_label(y, title):
    plt.figure(figsize=(14, 6))
    ax = sns.countplot(x=y, palette='inferno')
    plt.xlabel('Labels')
    plt.title(f'Class Counts of Fruit and Vegetable Images in {title} Data')
    
    # Her çubuğun üzerine sayıları ekleme
    for p in ax.patches:
        ax.annotate(f'{int(p.get_height())}', 
                    (p.get_x() + p.get_width() / 2., p.get_height()), 
                    ha='center', va='baseline', 
                    fontsize=12, color='black', 
                    xytext=(0, 2),  # Yüksekliği ayarlamak için
                    textcoords='offset points')
    
    plt.tight_layout()
    plt.show()

# Örnek kullanım
count_label(y_train, 'Images')

# %% [markdown]
# <a id="4.1"></a>
# ### Visualize Training Images

# %%
def plot_image(X,y,path):
    fig, axes = plt.subplots(6, 6, figsize=(10, 10))
    j=0
    for i,ax in enumerate(axes.flat):
        ax.imshow(X[j]) 
        ax.set_title(os.listdir(path)[i], fontsize=10) 
        ax.axis('off') 
        j+=(y == i).sum()
    plt.tight_layout(pad=0.3)  
    plt.show()

# %%
plot_image(X_train, y_train, train_path)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[117], line 1
# ----> 1 plot_image(X_train, y_train, train_path)
#
# Cell In[116], line 5, in plot_image(X, y, path)
#       3 j=0
#       4 for i,ax in enumerate(axes.flat):
# ----> 5     ax.imshow(X[j])
#       6     ax.set_title(os.listdir(path)[i], fontsize=10)
#       7     ax.axis('off')
#
# IndexError: index 6826 is out of bounds for axis 0 with size 6826

# %% [markdown]
# <a id="5"></a>
# ## 5-Data Augmentation

# %%
data_augmentation = Sequential([
    tf.keras.layers.RandomFlip('horizontal'),
    tf.keras.layers.RandomRotation(0.1),
    tf.keras.layers.RandomZoom(0.1),
    tf.keras.layers.RandomContrast(0.1)
])

# %%
train_dataset_aug = train_dataset.map(lambda x, y: (data_augmentation(x), y), num_parallel_calls=tf.data.AUTOTUNE)

# %% [markdown]
# <a id="6"></a>
# ## 6-Build and Train the Model

# %%
def plot_history(history):
    plt.figure(figsize=(12,4))
    plt.subplot(1,2,1)
    plt.plot(history.history['accuracy'], label='Train Accuracy')
    plt.plot(history.history['val_accuracy'], label='Val Accuracy')
    plt.ylim(0, 1)
    plt.yticks(np.arange(0, 1.1, 0.1)) 
    plt.legend()
    plt.title('Accuracy over epochs')
    
    plt.subplot(1,2,2)
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Val Loss')
    plt.legend()
    plt.title('Loss over epochs')
    plt.show()

# %%
test_images = []
test_labels = []

for img_batch, label_batch in test_dataset:
    test_images.extend(img_batch.numpy())
    test_labels.extend(label_batch.numpy())

test_images = np.array(test_images)
test_labels = np.array(test_labels)

# %%
def pred_and_cm(model):
    prediction_probs = model.predict(test_images)
    predictions = np.argmax(prediction_probs, axis=1)
    cm = confusion_matrix(test_labels, predictions)
    mask = (cm == 0)
    cm_safe = np.where(cm == 0, 1e-6, cm)
    plt.figure(figsize=(12,8))
    ax=sns.heatmap(    
    cm_safe,
    mask=mask, 
    annot=True,
    cmap='viridis',
    norm=LogNorm(vmin=1e-6, vmax=cm_safe.max()),
    xticklabels=label_list,
    yticklabels=label_list,
    annot_kws={'size':12})
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            if cm[i, j] == 0:
                ax.add_patch(plt.Rectangle((j, i), 1, 1, fill=True, color='azure', edgecolor='gray'))
    plt.title('Confusion Matrix')  
    plt.xlabel('Predicted Class')    
    plt.ylabel('True Class')              
                
    plt.show()

# %% [markdown]
# <a id="6.1"></a>
# ### Basic Model with no Augmentation

# %%
model_basic = models.Sequential([
    layers.Conv2D(32, (3, 3), activation='relu', padding='same',
                  kernel_regularizer=regularizers.l2(0.001),
                  input_shape=(128, 128 , 3)),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),

    layers.Conv2D(64, (3, 3), activation='relu', padding='same',
                  kernel_regularizer=regularizers.l2(0.001)),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),

    layers.Conv2D(128, (3, 3), activation='relu', padding='same',
                  kernel_regularizer=regularizers.l2(0.001)),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),

    layers.Conv2D(256, (3, 3), activation='relu', padding='same',
                  kernel_regularizer=regularizers.l2(0.001)),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),

    layers.GlobalAveragePooling2D(),

    layers.Dense(512, activation='relu',
                 kernel_regularizer=regularizers.l2(0.001)),
    layers.Dropout(0.2),
    layers.BatchNormalization(),

    layers.Dense(36, activation='softmax',
                 kernel_regularizer=regularizers.l2(0.001))
])

model_basic.compile(
    optimizer=Adam(learning_rate=0.001),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# Display the model summary
model_basic.summary()

early_stop = EarlyStopping(
    monitor='val_loss',
    patience=5,
    restore_best_weights=True
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=2,
    min_lr=1e-7
)

callbacks = [early_stop, reduce_lr]

history = model_basic.fit(
    train_dataset,
    epochs=20,
    validation_data=test_dataset,
    callbacks=callbacks,
    verbose=0
)

plot_history(history)
result_model_basic = pd.DataFrame(history.history)
# Out:
# Model: "sequential_12"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_20 (Conv2D)              │ (None, 128, 128, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_25          │ (None, 128, 128, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_20 (MaxPooling2D) │ (None, 64, 64, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_21 (Conv2D)              │ (None, 64, 64, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_26          │ (None, 64, 64, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_21 (MaxPooling2D) │ (None, 32, 32, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_22 (Conv2D)              │ (None, 32, 32, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_27          │ (None, 32, 32, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_22 (MaxPooling2D) │ (None, 16, 16, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_23 (Conv2D)              │ (None, 16, 16, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_28          │ (None, 16, 16, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_23 (MaxPooling2D) │ (None, 8, 8, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_7      │ (None, 256)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_18 (Dense)                │ (None, 512)            │       131,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_29          │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_19 (Dense)                │ (None, 36)             │        18,468 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 542,436 (2.07 MB)
#  Trainable params: 540,452 (2.06 MB)
#  Non-trainable params: 1,984 (7.75 KB)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[123], line 58
#      49 reduce_lr = ReduceLROnPlateau(
#      50     monitor='val_loss',
#      51     factor=0.5,
#      52     patience=2,
#      53     min_lr=1e-7
#      54 )
#      56 callbacks = [early_stop, reduce_lr]
# ---> 58 history = model_basic.fit(
#      59     train_dataset,
#      60     epochs=20,
#      61     validation_data=test_dataset,
#      62     callbacks=callbacks,
#      63     verbose=0
#      64 )
#      66 plot_history(history)
#      67 result_model_basic = pd.DataFrame(history.history)
#
# File c:\Users\cream\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\cream\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:377, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     375 for step, iterator in epoch_iterator:
#     376     callbacks.on_train_batch_begin(step)
# --> 377     logs = self.train_function(iterator)
#     378     callbacks.on_train_batch_end(step, logs)
#     379     if self.stop_training:
#
# File c:\Users\cream\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:220, in TensorFlowTrainer._make_function.<locals>.function(iterator)
#     216 def function(iterator):
#     217     if isinstance(
#     218         iterator, (tf.data.Iterator, tf.distribute.DistributedIterator)
#     219     ):
# --> 220         opt_outputs = multi_step_on_iterator(iterator)
#     221         if not opt_outputs.has_value():
#     222             raise StopIteration
#
# File c:\Users\cream\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\cream\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\Users\cream\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File c:\Users\cream\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File c:\Users\cream\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\eager\polymorphic_function\concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File c:\Users\cream\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File c:\Users\cream\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File c:\Users\cream\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\eager\context.py:1688, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1686 cancellation_context = cancellation.context()
#    1687 if cancellation_context is None:
# -> 1688   outputs = execute.execute(
#    1689       name.decode("utf-8"),
#    1690       num_outputs=num_outputs,
#    1691       inputs=tensor_inputs,
#    1692       attrs=attrs,
#    1693       ctx=self,
#    1694   )
#    1695 else:
#    1696   outputs = execute.execute_with_cancellation(
#    1697       name.decode("utf-8"),
#    1698       num_outputs=num_outputs,
#    (...)   1702       cancellation_manager=cancellation_context,
#    1703   )
#
# File c:\Users\cream\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
result_model_basic.tail(5)
# Out:
#     accuracy      loss  val_accuracy  val_loss  learning_rate
# 15  0.933099  0.711821      0.917411  0.714609        0.00025
# 16  0.921948  0.706315      0.950893  0.655439        0.00025
# 17  0.929977  0.688776      0.955189  0.611961        0.00025
# 18  0.937207  0.673773      0.939732  0.647250        0.00025
# 19  0.936033  0.655745      0.877232  0.862230        0.00025

# %%
pred_and_cm(model_basic)
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step

# %% [markdown]
# <a id="6.2"></a>
# ### Basic Model with Augmentation

# %%
model_basic_aug = models.Sequential([
    layers.Conv2D(32, (3, 3), activation='relu', padding='same',
                  kernel_regularizer=regularizers.l2(0.01),
                  input_shape=(128, 128 , 3)),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),

    layers.Conv2D(64, (3, 3), activation='relu', padding='same',
                  kernel_regularizer=regularizers.l2(0.001)),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),

    layers.Conv2D(128, (3, 3), activation='relu', padding='same',
                  kernel_regularizer=regularizers.l2(0.001)),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),

    layers.Conv2D(256, (3, 3), activation='relu', padding='same',
                  kernel_regularizer=regularizers.l2(0.001)),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),
    
    layers.Flatten(),

    layers.Dense(512, activation='relu',
                 kernel_regularizer=regularizers.l2(0.001)),
    layers.Dropout(0.2),
    layers.BatchNormalization(),

    layers.Dense(36, activation='softmax',
                 kernel_regularizer=regularizers.l2(0.001))
])

model_basic_aug.compile(
    optimizer=Adam(learning_rate=0.001),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)


early_stop = EarlyStopping(
    monitor='val_loss',
    patience=10,
    restore_best_weights=True
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=2,
    min_lr=1e-7
)

callbacks = [early_stop, reduce_lr]

history = model_basic_aug.fit(
    train_dataset_aug,
    epochs=20,
    validation_data=test_dataset,
    callbacks=callbacks,
    verbose=0
)

plot_history(history)
result_model_basic_aug = pd.DataFrame(history.history)

# %%
result_model_basic_aug.tail()
# Out:
#     accuracy      loss  val_accuracy  val_loss  learning_rate
# 15  0.876174  0.962161      0.850446  0.929567        0.00050
# 16  0.876174  0.936843      0.774554  1.242088        0.00050
# 17  0.889085  0.844809      0.935268  0.735365        0.00025
# 18  0.920139  0.766358      0.928571  0.736181        0.00025
# 19  0.914319  0.749929      0.866071  0.847517        0.00025

# %%
pred_and_cm(model_basic_aug)
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step

# %% [markdown]
# #### Basic Model Visualization

# %%
vis_path = '/kaggle/working/basic_model.png'
visualkeras.layered_view(model_basic, to_file=vis_path, legend=True)

img = Image.open(vis_path)
plt.figure(figsize=(10,10))
plt.imshow(img)
plt.axis('off')
plt.show()

# %% [markdown]
# <a id="6.3"></a>
# ### MobileNetV2 Model with no Augmentation

# %%
mobile_net_model = keras.applications.MobileNetV2(input_shape=(128,128,3), 
                                                 include_top=False, weights='imagenet')
mobile_net_model.trainable = True 
for layer in mobile_net_model.layers[:-20]:
    layer.trainable = False

model_mnV2 = keras.Sequential([
    mobile_net_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(256, activation='relu'),
    layers.Dropout(0.3),
    layers.Dense(num_classes, activation='softmax')
])

model_mnV2.compile(
    optimizer=Adam(learning_rate=0.0001),
    loss='sparse_categorical_crossentropy',
    metrics =['accuracy']
)

early_stop = EarlyStopping(
    monitor='val_loss',
    patience=8,
    restore_best_weights=True
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.1,
    patience=2,
    min_lr=1e-7
)

callbacks = [early_stop, reduce_lr]

history = model_mnV2.fit(
    train_dataset,
    epochs=20,
    validation_data=test_dataset,
    callbacks=callbacks,
    verbose=0
)
plot_history(history)
result_mobile_net_model = pd.DataFrame(history.history)
model_mnV2.save('/kaggle/working/model_fruits_and_vegatables.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
result_mobile_net_model.tail(5)
# Out:
#     accuracy      loss  val_accuracy  val_loss  learning_rate
# 15  0.998826  0.009098           1.0  0.002563        0.00001
# 16  0.999421  0.009750           1.0  0.001436        0.00001
# 17  0.999413  0.007139           1.0  0.001445        0.00001
# 18  1.000000  0.007280           1.0  0.000955        0.00001
# 19  0.998826  0.008053           1.0  0.001198        0.00001

# %%
pred_and_cm(model_mnV2)
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step

# %% [markdown]
# <a id="6.4"></a>
# ### MobileNetV2 Model with Augmentation

# %%
mobile_net_model = keras.applications.MobileNetV2(input_shape=(128,128,3), 
                                                 include_top=False, weights='imagenet')
mobile_net_model.trainable = True 
for layer in mobile_net_model.layers[:-20]:
    layer.trainable = False

model_mnV2_aug = keras.Sequential([
    mobile_net_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(256, activation='relu'),
    layers.Dropout(0.3),
    layers.Dense(num_classes, activation='softmax')
])

model_mnV2_aug.compile(
    optimizer=Adam(learning_rate=0.0001),
    loss='sparse_categorical_crossentropy',
    metrics =['accuracy']
)

early_stop = EarlyStopping(
    monitor='val_loss',
    patience=5,
    restore_best_weights=True
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=2,
    min_lr=1e-7
)

callbacks = [early_stop, reduce_lr]

history = model_mnV2_aug.fit(
    train_dataset_aug,
    epochs=20,
    validation_data=test_dataset,
    callbacks=callbacks,
    verbose=0
)
plot_history(history)
result_mobile_net_model_aug = pd.DataFrame(history.history)

# %%
result_mobile_net_model_aug.tail(5)
# Out:
#     accuracy      loss  val_accuracy  val_loss  learning_rate
# 15  0.940550  0.183829      0.942587  0.155016       0.000025
# 16  0.945321  0.176802      0.958576  0.104953       0.000025
# 17  0.942385  0.179701      0.958576  0.109961       0.000025
# 18  0.946239  0.158566      0.953488  0.123472       0.000025
# 19  0.950841  0.148808      0.966570  0.096610       0.000012

# %%
pred_and_cm(model_mnV2_aug)
# Out:
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 4s 77ms/step

# %% [markdown]
# #### model_mnV2 Visualization

# %%
visualkeras.layered_view(mobile_net_model,to_file=vis_path, scale_xy=50)

img = Image.open(vis_path)
plt.figure(figsize=(30,30))
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
vis_path = '/kaggle/working/model_mnV2.png'
visualkeras.layered_view(model_mnV2, to_file=vis_path, legend=True)

img = Image.open(vis_path)
plt.figure()
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
model_mnV2_aug.save('model_mnV2_aug.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
from tensorflow.keras.models import load_model
from tensorflow.keras.utils import load_img, img_to_array
import tensorflow as tf

# 載入模型
model_mnV2_aug_load = load_model('model_mnV2_aug.h5')

# 載入圖片
img = load_img("長南瓜.jpg", target_size=(128, 128))
img_array = img_to_array(img) / 255.0
img_array = tf.expand_dims(img_array, axis=0)  # shape: (1, 224, 224, 3)

print(classes)

# 預測
pred = model_mnV2_aug_load.predict(img_array)
pred = tf.argmax(pred, axis=1).numpy()[0]
print(pred)
print(classes[pred])
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# ['Baby Corn', 'Beef Tomato', 'Chinese chives', 'French beans', 'Garlic sprouts', 'Green bamboo shoots', 'Okra', 'Shallots', 'Sweet potato leaves', 'Water Lily', 'White radish', 'Winter melon', 'asparagus', 'chili', 'coriander', 'onion', 'pumpkin', 'sweet potato', 'zucchini']
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 600ms/step
# 16
# pumpkin

# %% [markdown]
# <a id="7"></a>
# ## 7-Result

# %% [markdown]
# I experimented with four different models and achieved successful results with all of them. My custom models performed as well as MobileNetV2, although they required significantly more time to reach the same level of accuracy. While the models initially struggled with learning under data augmentation, I was ultimately able to overcome these challenges.

# %% [markdown]
# <span style="background: linear-gradient(to right, #FF5733, #33FF57, #3357FF, #FF33A1);
#     -webkit-background-clip: text; -webkit-text-fill-color: transparent; font-size: 40px; font-weight: bold">
#     Thanks for Reading :)
# </span>
